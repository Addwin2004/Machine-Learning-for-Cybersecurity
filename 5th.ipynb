# %%
# SVM - URL Classification

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Sample URL dataset
data = {
    "url_length": [20, 25, 30, 80, 100, 90, 22, 28, 85, 110],
    "has_https": [1, 1, 1, 0, 0, 0, 1, 1, 0, 0],
    "has_ip": [0, 0, 0, 1, 1, 1, 0, 0, 1, 1],
    "label": [0, 0, 0, 1, 1, 1, 0, 0, 1, 1]
}

df = pd.DataFrame(data)

# Features and target
X = df[["url_length", "has_https", "has_ip"]]
y = df["label"]

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create SVM model
model = SVC(kernel="linear")

# Train model
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=0))

# Test a new URL
new_url = [[75, 0, 1]]

prediction = model.predict(new_url)

if prediction[0] == 1:
    print("\nURL: Malicious")
else:
    print("\nURL: Legitimate")
# Out:
# Accuracy: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# URL: Malicious
# C:\Users\ADDWIN\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
